# %%
from scipy import stats
import math
import time
import matplotlib.pyplot as plt
import subprocess

# no scaling: 3.149058889251307
# scaling: 1.9994004817225839
# someone else's scaling: 2.01
# pushrelabel: 2.023
vals = []
vals += [100*i for i in range(15, 30)]
results = []
iters = 10
for v in vals:
    total = 0
    for i in range(iters):
        subprocess.Popen(f"./gen {v} > input.txt", shell=True).wait()
        begin = time.time()
        subprocess.Popen(f"./main < input.txt", shell=True).wait()
        total += time.time()-begin
    results.append(total/iters)

# %%
vals, results = [math.log(i) for i in vals], [math.log(i) for i in results]

# %%
print(vals, results)
plt.plot(vals, results)
slope, _, _, _, _ = stats.linregress(vals, results)
print(slope)
# Out:
# [7.313220387090301, 7.3777589082278725, 7.438383530044307, 7.495541943884256, 7.549609165154532, 7.600902459542082, 7.649692623711514, 7.696212639346407, 7.7406644019172415, 7.783224016336037, 7.824046010856292, 7.8632667240095735, 7.90100705199242, 7.937374696163295, 7.9724660159745655] [-2.183953858945669, -2.0123250480194916, -1.8698858295115088, -1.7944620161358082, -1.6917956698968641, -1.611706294234343, -1.4571619711290715, -1.4076006111950916, -1.298934754961439, -1.2557467656840466, -1.1873966952586656, -1.1122390197612486, -1.073805706861491, -0.9940402837047286, -0.95981337822539]
# 1.83321969552807

# %%
print(valsno, resultsno)
plt.plot([i - (min(valsno) - min(vals)) for i in valsno], [i - (min(resultsno) - min(results)) for i in resultsno])
plt.plot(vals, results)
slope, _, _, _, _ = stats.linregress(valsno, resultsno)
print(slope)
# Out:
# [6.907755278982137, 7.003065458786462, 7.090076835776092, 7.170119543449628, 7.24422751560335, 7.313220387090301, 7.3777589082278725, 7.438383530044307, 7.495541943884256, 7.549609165154532, 7.600902459542082, 7.649692623711514, 7.696212639346407, 7.7406644019172415, 7.783224016336037] [1.7231272429810727, 2.000382156837061, 2.2702315896884766, 2.5282583969537473, 2.761371222146484, 2.9612020990012824, 3.166593151210979, 3.3737406677590767, 3.526601590034595, 3.721818181325533, 3.8941186530111414, 4.063942699725527, 4.2220446226664885, 4.388770978021582, 4.530159793437009]
# 3.2043500985586477
